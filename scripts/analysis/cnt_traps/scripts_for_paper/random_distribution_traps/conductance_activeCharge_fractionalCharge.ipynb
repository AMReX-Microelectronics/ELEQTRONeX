# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as ticker
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
plt.rcParams.update({'font.size': 12})
import seaborn as sns
import cmath
import math 
from numpy.linalg import inv
def custom_plot_single(fig, ax1, x_lst, y_lst, label_lst, xlim, ylim, label,pltname,
                       color=['k','r','b','g','o']*1,
                       linestyle=['solid','dashed','solid','dashed','solid','dashed'],
                       markertype=[None]*50,
                       fillstyle=['none']*50,
                       linewidth=50*[3],
                       markevery=[1]*50,
                       show_legend=True,
                       plt_outside=False, y_logscale = False):
    
    fig.patch.set_facecolor('white')
    ax1.patch.set_facecolor('white')

    for p in range(0, len(x_lst)):
        ax1.plot(x_lst[p], y_lst[p], color[p],
                 linewidth=linewidth[p],
                 #linestyle=linestyle[p],
                 marker=markertype[p],
                 fillstyle=fillstyle[p],
                 markevery=markevery[p],
                 markersize=12,
                 label=label_lst[p])
    ax1.tick_params(which='minor', width=2, length=4, color='k')
    ax1.tick_params(which='major', width=2, length=8, color='k')

    ax1.xaxis.set_minor_locator(ticker.AutoMinorLocator())
    ax1.yaxis.set_minor_locator(ticker.AutoMinorLocator())
    if(show_legend):
        ax1.legend(prop={'size': 24},loc='best',shadow=True,frameon=False)#,bbox_to_anchor=(1.01,1.0))
    if (y_logscale):
        ax1.set_yscale('log')
    ax1.set_ylim(ylim[0],ylim[1])
    ax1.set_xlim(xlim[0],xlim[1])
    ax1.set_xlabel(label[0], fontsize=30)#, fontdict=dict(weight='bold'))
    ax1.set_ylabel(label[1], fontsize=30)#, fontdict=dict(weight='bold'))
    fontsize=30
    for tick in ax1.xaxis.get_major_ticks():
        tick.label1.set_fontsize(fontsize)

    for tick in ax1.yaxis.get_major_ticks():
        tick.label1.set_fontsize(fontsize)
    for spine in ax1.spines.values():
        spine.set_linewidth(2)  # Increase the frame thickness              
    if(plt_outside==False):
        plt.savefig(pltname, bbox_inches = "tight")
    return plt,pltname

PrintFigures=True
PointCharge=True

# %%
import pandas as pd
folder_path = '../figures_exp/'
Fig1d = pd.read_csv(folder_path  + 'fig1d.csv', header=None)

Vgs_exp  = Fig1d[0].to_numpy()
Ids_exp  = Fig1d[1].to_numpy()

# %%
#quantum of conductance
#https://physics.nist.gov/cgi-bin/cuu/Value?conqu2e2sh
#G_quantum=2e^2/h, q=1.602e-19, h = 6.62607e-34
G_quantum  = 7.748091729e-5 #[S] 

#num_CNTs = 1
Vds = 0.1
CNT_spacing = 2.556e-3
pts_max  = 64

variable_occupation = []
foldername = [] 
label_str = []
Color = []

foldername.append('../periodic/with_point_charge/no_charge/EfmDot2')
label_str.append(r'$E_f=-0.2$, $\rho_p=0$')
Color.append('k')
variable_occupation.append(False)

# foldername.append('../periodic/with_point_charge/rhoDot7/Et0Dot02_Vo0Dot5_EfmDot2')
# label_str.append(r'(3D) $\rho_p = 0.7$ e/nm$^3$, $V_t=0.02$, $V_o=0.5$, $E_f=-0.2$')
# Color.append('k--')
# variable_occupation.append(False)

# foldername.append('../periodic/with_point_charge/rho1Dot5_2D/RandomSeed1_4dz')
# label_str.append(r'(3D) $\rho_p = 0.7$ e/nm$^3$, $V_t=0.02$, $V_o=0.5$, $E_f=-0.2$')
# Color.append('k--')
# variable_occupation.append(False)

# foldername.append('../periodic/with_point_charge/rho1Dot5_2D/RandomSeed1_4dz')
# label_str.append(r'RandomSeed1')
# Color.append('g--')
# variable_occupation.append(False)

Distribution3DRandomStart=1
foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed1')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed2')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed3')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed4')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed5')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed6')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed7')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed8')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed9')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed10')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed11')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed12')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed13')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed14')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed15')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed16')
variable_occupation.append(True)

Distribution3DRandomEnd=Distribution3DRandomStart+16

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed1')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed2')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed3')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed4')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed5')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed6')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed7')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed8')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed9')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed10')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed11')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed12')
variable_occupation.append(True)

# foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed13')
# variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed14')
variable_occupation.append(True)

foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed15')
variable_occupation.append(True)

# foldername.append('../periodic/with_point_charge/rho1Dot6_2D/RandomSeed16')
# variable_occupation.append(True)
Distribution2DRandomEnd = Distribution3DRandomEnd + 14

print('Distribution3DRandomStart', Distribution3DRandomStart)
print('Distribution3DRandomEnd', Distribution3DRandomEnd)
print('Distribution2DRandomEnd', Distribution2DRandomEnd)
# Out:
# Distribution3DRandomStart 1
# Distribution3DRandomEnd 17
# Distribution2DRandomEnd 31

# %%
num_folders=np.size(foldername)
Vgs =  np.zeros((num_folders, pts_max),dtype=float)
G   = np.zeros((num_folders, pts_max),dtype=float)
Ids_appx = np.zeros((num_folders, pts_max),dtype=float)
pts = np.zeros(num_folders,dtype=int)
pts[:] = pts_max

# %%
for folder in range(num_folders):
    file_path = f"{foldername[folder]}/negf/NS_1/I.dat"
    print(str(folder) +  str(file_path))
    data = np.loadtxt(file_path, skiprows=1, usecols=(2, 7))  # Vgs = col[2], G = col[7]

    vgs_arr = data[:, 0] 
    g_arr = data[:, 1] 

    pts[folder] = len(vgs_arr)
    Vgs[folder][:pts[folder]] = vgs_arr
    G[folder][:pts[folder]] = g_arr
    Ids_appx[folder] =  G[folder]*G_quantum*Vds/CNT_spacing
# Out:
# 0../periodic/with_point_charge/no_charge/EfmDot2/negf/NS_1/I.dat
# 1../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed1/negf/NS_1/I.dat
# 2../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed2/negf/NS_1/I.dat
# 3../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed3/negf/NS_1/I.dat
# 4../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed4/negf/NS_1/I.dat
# 5../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed5/negf/NS_1/I.dat
# 6../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed6/negf/NS_1/I.dat
# 7../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed7/negf/NS_1/I.dat
# 8../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed8/negf/NS_1/I.dat
# 9../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed9/negf/NS_1/I.dat
# 10../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed10/negf/NS_1/I.dat
# 11../periodic/with_point_charge/rhoDot7_RandomSeed/RandomSeed11/negf/NS_1/I.dat
# ...

# %%
def Get_MeanAndStd(Var):

    n_folders, n_pts = Var.shape
    NewVar =  np.zeros((3, n_pts),dtype=float)

    mean = np.mean(Var, axis=0)
    stddev = np.std(Var, axis=0)
    hi = mean + 1*stddev
    lo = mean - 1*stddev

    NewVar[0] = mean
    NewVar[1] = lo
    NewVar[2] = hi

    assert NewVar.shape == (3, n_pts)

    return NewVar
    #print("\n")

# %%
Vgs_3d_distrib = Get_MeanAndStd(Vgs[Distribution3DRandomStart:Distribution3DRandomEnd])
Ids_3d_distrib = Get_MeanAndStd(Ids_appx[Distribution3DRandomStart:Distribution3DRandomEnd])
pts_valid =21

Vgs_3d_mean = Vgs_3d_distrib[0][:pts_valid]
Ids_3d_mean = Ids_3d_distrib[0][:pts_valid]   # Mean 
Ids_3d_lower = Ids_3d_distrib[1][:pts_valid]  # Mean - stddev
Ids_3d_upper = Ids_3d_distrib[2][:pts_valid]  # Mean + stddev

# %%
Vgs_2d_distrib = Get_MeanAndStd(Vgs[Distribution3DRandomEnd:Distribution2DRandomEnd])
Ids_2d_distrib = Get_MeanAndStd(Ids_appx[Distribution3DRandomEnd:Distribution2DRandomEnd])
pts_valid = 21

Vgs_2d_mean = Vgs_2d_distrib[0][:pts_valid]
Ids_2d_mean = Ids_2d_distrib[0][:pts_valid]   # Mean 
Ids_2d_lower = Ids_2d_distrib[1][:pts_valid]  # Mean - stddev
Ids_2d_upper = Ids_2d_distrib[2][:pts_valid]  # Mean + stddev

# %%
if PrintFigures: 
    #fig, ax = plt.subplots(1, 1)
    #fig.set_size_inches(10, 7)    
    fig = plt.figure(figsize=(12,8), constrained_layout=True)
    ax = fig.add_axes([0.18,0.15,0.8,0.8])
    # Custom plot function for main curves
    plt, pltname = custom_plot_single(fig, ax,
                                      [Vgs_exp] + [Vgs[0][:pts[0]]] + [Vgs_3d_mean] + [Vgs_2d_mean], 
                                      [Ids_exp] + [Ids_appx[0][:pts[0]]] + [Ids_3d_mean] + [Ids_2d_mean],                                     
                                      [r'experiment', 'no trap', r'3D trap distribution', '2D trap distribution'],
                                      [-1.4, 0.5],
                                      [1e-10, 1e-3],
                                      [r'Gate-source voltage, $V_{gs}$ / (V)', r'Drain-source current, I$_{ds}$ (A $\mu$m$^{-1}$)'],
                                      'G_exp_3D_2D.png',
                                      color=['r','k','b--','g--'],
                                      linestyle=['solid','solid','dashed','dashed'],
                                      markertype=[None] * 10,
                                      markevery=[1] * 10,
                                      linewidth=[3] * 10,
                                      fillstyle=['none'] * 10,                                    
                                      show_legend=True,
                                      plt_outside=True,
                                      y_logscale=True)
    ax.set_xticks(np.arange(-1.5, 0.6, 0.5))  # X-axis ticks from -1.5 to 0.5 with a step of 0.5

    # Adding shaded regions (stddev)
    ax.fill_between(Vgs_3d_mean, Ids_3d_lower, Ids_3d_upper, color='blue', alpha=0.2, label="3D stddev")
    ax.fill_between(Vgs_2d_mean, Ids_2d_lower, Ids_2d_upper, color='green', alpha=0.2, label="2D stddev")

    # Add text annotation
    plt.text(-1.3, 2e-6, r'$V_{ds}$ = -0.1 V', fontsize=30, color='k')
    plt.text(-0.99, 1.3e-7, r'SS=174 $\pm$ 2'+'\n'+'       mV/dec', fontsize=30, color='b')
    plt.text(-0.17, 1.3e-7, r'157 $\pm$ 4'+'\n'+'mV/dec', fontsize=30, color='g')

    # Save figure
    plt.savefig(pltname, bbox_inches="tight", dpi='figure', format='png', pad_inches=0.1, facecolor='white', edgecolor='auto')
# Out:
# /home/saru/sata/codes/lbnl/ELEQTRONeX/Analysis/Topgate/charge_distrib_expconfig/ForPaper/utils_SS.py:25: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b--" (-> linestyle='--'). The keyword argument will take precedence.
#   ax1.plot(x_lst[p], y_lst[p], color[p],
# /home/saru/sata/codes/lbnl/ELEQTRONeX/Analysis/Topgate/charge_distrib_expconfig/ForPaper/utils_SS.py:25: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g--" (-> linestyle='--'). The keyword argument will take precedence.
#   ax1.plot(x_lst[p], y_lst[p], color[p],
# /tmp/ipykernel_476554/3134337038.py:36: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   plt.savefig(pltname, bbox_inches="tight", dpi='figure', format='png', pad_inches=0.1, facecolor='white', edgecolor='auto')
# ...

# %% [markdown]
# ## Model
# $$Q_i = e sigmoid\left(\frac{eV_o - eV_i}{eV_t}\right)$$
# $$V_i = V(\textbf{r}_i)$$
# $eV_o =$ trap energy level
#
# $V_t =$ parameter to transition between empty and filled gaps
# ## Parameters used to make the above figure for 3D and 2D distributions
# $E_f =$ -0.2 eV
#
# $V_o =$ 0.5 V
#
# $V_t =$ 0.02 V
#
# Density of traps, $\rho_p=$ 0.7 e/nm^3 (for 3D distribution) and $\rho_p=$1.6 e/nm^2 (for 2D distribution)

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def plot_all_charges(plt, foldername, variable_occupation, label_str, Color):
    all_Vgs_values = []
    all_total_charge_values = []
    all_fractional_active_charge_values = []
    
    for i, folder in enumerate(foldername):
        #print(i,folder,variable_occupation[i])
        if variable_occupation[i]:
            filename = folder + '/point_charge/total_charge_vs_step.dat'
            steps = []
            Vgs_values = []
            total_charge_values = []
            fractional_active_charge_values = []
            
            with open(filename, 'r') as file:
                lines = file.readlines()[1:]  # Skip the header
                current_step = None
                
                for line in lines:
                    cols = line.split()
                    #print(cols) #for debugging
                    step = int(cols[0])
                    Vgs = float(cols[2])
                    total_charge = float(cols[4])
                    fractional_active_charge = float(cols[5])
                    
                    # Check if the step has changed
                    if step != current_step:
                        if current_step is not None:
                            # Store the last entry before the step change
                            Vgs_values.append(last_Vgs)
                            total_charge_values.append(last_total_charge)
                            fractional_active_charge_values.append(last_fractional_active_charge)
                        current_step = step
                    
                    # Store the last values in the current step
                    last_Vgs = Vgs
                    last_total_charge = total_charge
                    last_fractional_active_charge = fractional_active_charge
                
                # Append the last set of values after the loop ends
                Vgs_values.append(last_Vgs)
                total_charge_values.append(last_total_charge)
                fractional_active_charge_values.append(last_fractional_active_charge)
            
            all_Vgs_values.append(Vgs_values)
            all_total_charge_values.append(total_charge_values)
            all_fractional_active_charge_values.append(fractional_active_charge_values)

    return np.array(all_Vgs_values), np.array(all_total_charge_values), np.array(all_fractional_active_charge_values)

# %%
all_Vgs_values, all_total_charge_values, all_fractional_active_charge_values = plot_all_charges(plt, foldername, variable_occupation, label_str, Color)

# %% [markdown]
# Note first data file we read (no pt charge) was not included in this dataset.

# %% [markdown]
# ### Also note:
# all_Vgs_values should contain Vgs values for all files that had `variable_occupation.append(True)` while reading the data.
# However, while outputting the data to the total_charge_vs_step.dat there was an error in the code that outputted Vgs values as integers instead of doubles. That led to printing of Vgs values  as 0 or -1. instead of a range from 0.5 to -1.6 (with a spacing of 0.1). The other data is correct. So instead of rerunning the simulation, I am using Vgs values from `Vgs_3d_mean` during printing.
# I have corrected the error in the code since then and the above code block should work as expected for new runs.

# %%
np.shape(all_total_charge_values)
# Out:
# (30, 21)

# %% [markdown]
# ## Compute mean over all datasets for 3D and 2D distributions.

# %%
total_charge_values_3d_distrib = Get_MeanAndStd(all_total_charge_values[:16])
all_fractional_active_charge_values_3d_distrib = Get_MeanAndStd(all_fractional_active_charge_values[:16])

total_charge_values_3d_mean = total_charge_values_3d_distrib[0]
total_charge_values_3d_lo = total_charge_values_3d_distrib[1]
total_charge_values_3d_hi = total_charge_values_3d_distrib[2]

fractional_active_charge_values_3d_mean = all_fractional_active_charge_values_3d_distrib[0]
fractional_active_charge_values_3d_lo = all_fractional_active_charge_values_3d_distrib[1]
fractional_active_charge_values_3d_hi = all_fractional_active_charge_values_3d_distrib[2]

# %%
total_charge_values_2d_distrib = Get_MeanAndStd(all_total_charge_values[16:])
all_fractional_active_charge_values_2d_distrib = Get_MeanAndStd(all_fractional_active_charge_values[16:])

# %%
total_charge_values_2d_mean = total_charge_values_2d_distrib[0]
total_charge_values_2d_lo = total_charge_values_2d_distrib[1]
total_charge_values_2d_hi = total_charge_values_2d_distrib[2]

fractional_active_charge_values_2d_mean = all_fractional_active_charge_values_2d_distrib[0]
fractional_active_charge_values_2d_lo = all_fractional_active_charge_values_2d_distrib[1]
fractional_active_charge_values_2d_hi = all_fractional_active_charge_values_2d_distrib[2]

# %%
if PrintFigures: 
    fig = plt.figure(figsize=(12,8), constrained_layout=True)
    ax = fig.add_axes([0.18,0.15,0.8,0.8])
    custom_ls_pattern=(0, (3, 2, 1, 2, 1, 2))

    plt,pltname = custom_plot_single(fig, ax,
        x_lst=[Vgs_3d_mean, Vgs_2d_mean],
        y_lst=[total_charge_values_3d_mean, total_charge_values_2d_mean],
        label_lst=['3D trap distribution', '2D trap distribution'],                            
        xlim=[-1.5, 0.5],
        ylim=[0, 250],
        label=['Gate-source voltage, $V_{gs}$ / (V)', 'Total active charge / (e)'],
        pltname='total_charge_3D_2D.png',
        color=['b--','g--'],
    )
    # Adding shaded regions (stddev)
    ax.fill_between(Vgs_3d_mean, total_charge_values_3d_lo, total_charge_values_3d_hi, color='blue', alpha=0.2, label="3D stddev")
    ax.fill_between(Vgs_2d_mean, total_charge_values_2d_lo, total_charge_values_2d_hi, color='green', alpha=0.2, label="2D stddev")
    ax.set_xticks(np.arange(-1.5, 0.6, 0.5))  # X-axis ticks from -1.5 to 0.5 with a step of 0.5
    plt.savefig(pltname, bbox_inches="tight", dpi='figure', format='png', pad_inches=0.1, facecolor='white', edgecolor='auto')
# Out:
# /tmp/ipykernel_476554/2687152427.py:57: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   plt.savefig(pltname, bbox_inches = "tight")
# /tmp/ipykernel_476554/2342360325.py:20: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   plt.savefig(pltname, bbox_inches="tight", dpi='figure', format='png', pad_inches=0.1, facecolor='white', edgecolor='auto')
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:151: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
if PrintFigures: 
    fig = plt.figure(figsize=(12,8), constrained_layout=True)
    ax = fig.add_axes([0.18,0.15,0.8,0.8])
    custom_ls_pattern=(0, (3, 2, 1, 2, 1, 2))

    plt,pltname = custom_plot_single(fig, ax,
        x_lst=[Vgs_3d_mean, Vgs_2d_mean],
        y_lst=[fractional_active_charge_values_3d_mean, fractional_active_charge_values_2d_mean],
        label_lst=['3D trap distribution', '2D trap distribution'],                            
        xlim=[-1.5, 0.5],
        ylim=[0,0.4],
        label=['$V_{gs}$ / (V)', 'Fractional Active Charge'],
        pltname='fractional_charge_3D_2D.png',
        color=['b--','g--'],
    )
    # Adding shaded regions (stddev)
    ax.fill_between(Vgs_3d_mean, fractional_active_charge_values_3d_lo, fractional_active_charge_values_3d_hi, color='blue', alpha=0.2, label="3D stddev")
    ax.fill_between(Vgs_2d_mean, fractional_active_charge_values_2d_lo, fractional_active_charge_values_2d_hi, color='green', alpha=0.2, label="2D stddev")
    ax.set_xticks(np.arange(-1.5, 0.6, 0.5))  # X-axis ticks from -1.5 to 0.5 with a step of 0.5
# Out:
# /tmp/ipykernel_476554/2687152427.py:57: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   plt.savefig(pltname, bbox_inches = "tight")
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:151: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Computation of SS

# %%
from utils_SS import *

vgs_at_akT=-0.37675908209268194 # akT=9kT (calculated in SS_versus_density.ipynb
vgs_at_bkT=-0.23435275432947517 # bkT=11kT
# Here we use the vgs values calculated for random_seed=0 in SS_versus_density.ipynb file
# corresponding to rho_p=0.7e/nm^3, because the std dev is low.
SS_mean = compute_SS(Vgs_3d_mean,Ids_3d_mean*CNT_spacing/(G_quantum*Vds),vgs_at_akT, vgs_at_bkT, True)
SS_upper = compute_SS(Vgs_3d_mean,Ids_3d_upper*CNT_spacing/(G_quantum*Vds),vgs_at_akT, vgs_at_bkT, True)
SS_lower = compute_SS(Vgs_3d_mean,Ids_3d_lower*CNT_spacing/(G_quantum*Vds),vgs_at_akT, vgs_at_bkT, True)
print('mean (3D): ' ,SS_mean)
print('avg. std dev (2D): ', (abs(SS_upper-SS_mean) + abs(SS_mean-SS_lower))/2.)
# Out:
# 	SS (mV/decade): 173.6
# 	SS (mV/decade): 172.1
# 	SS (mV/decade): 176.3
# mean (3D):  173.64454056162603
# avg. std dev (2D):  2.1100596231361237

# %%
vgs_at_akT=-0.2277131350407708 # akT=9kT (calculated in SS_versus_density.ipynb
vgs_at_bkT=-0.1059948703439452 # bkT=11kT
# Here we use the vgs values calculated for random_seed=0 in SS_versus_density.ipynb file
# corresponding to rho_p=1.6e/nm^2, because the std dev is low.
SS_mean = compute_SS(Vgs_2d_mean,Ids_2d_mean*CNT_spacing/(G_quantum*Vds),vgs_at_akT, vgs_at_bkT, True)
SS_upper = compute_SS(Vgs_2d_mean,Ids_2d_upper*CNT_spacing/(G_quantum*Vds),vgs_at_akT, vgs_at_bkT, True)
SS_lower = compute_SS(Vgs_2d_mean,Ids_2d_lower*CNT_spacing/(G_quantum*Vds),vgs_at_akT, vgs_at_bkT, True)
print('mean (2D): ', SS_mean)
print('avg. std dev (2D): ', (abs(SS_upper-SS_mean) + abs(SS_mean-SS_lower))/2.)
# Out:
# 	SS (mV/decade): 157.2
# 	SS (mV/decade): 154.2
# 	SS (mV/decade): 162.4
# mean (2D):  157.17427728629076
# avg. std dev (2D):  4.116971727324369
